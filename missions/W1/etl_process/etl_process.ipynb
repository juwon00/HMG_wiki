# %%
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bs4 in /Users/admin/Library/Python/3.9/lib/python/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /Users/admin/Library/Python/3.9/lib/python/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/admin/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->bs4) (2.5)

# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /Users/admin/Library/Python/3.9/lib/python/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/admin/Library/Python/3.9/lib/python/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/admin/Library/Python/3.9/lib/python/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/admin/Library/Python/3.9/lib/python/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/admin/Library/Python/3.9/lib/python/site-packages (from requests) (2024.6.2)

# %%
# !pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in /Users/admin/Library/Python/3.9/lib/python/site-packages (5.2.2)

# %%
import requests
from bs4 import BeautifulSoup
# Out:
# /Users/admin/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"
response = requests.get(url)
response.raise_for_status()

soup = BeautifulSoup(response.text, "lxml")  # html.parser

# %%
table = soup.find("table", class_="wikitable")

# %%
tbody = table.find("tbody")

# %%
gdp = []

for i, tr in enumerate(tbody.find_all("tr")):
    row_data = {}
    for j, td in enumerate(tr.find_all("td")):
        if j == 0:  # 첫 번째 td에서 국가 이름 추출
            a_tag = td.find("a")
            if a_tag:
                row_data["Country"] = a_tag.text.strip()
            else:
                row_data["Country"] = td.text.strip()

        if j == 1 and td.text.strip() != "—":
            row_data["GDP_USD_billion"] = round(
                int(td.text.strip().replace(",", "")) / 1000, 2
            )

        if j == 2 and len(row_data) == 2:
            if len(td.text.strip()) > 4:
                row_data["Year"] = td.text.strip()[-4:]
            elif len(td.text.strip()) == 4:
                row_data["Year"] = td.text.strip()
    if len(row_data) > 1:
        gdp.append(row_data)

for g in gdp:
    g

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from io import StringIO
from etl_project_gdp import *


def make_df():
    log("extract start")
    url = "https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"
    response = requests.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, "html.parser")

    # HTML에서 테이블을 DataFrame으로 읽어오기
    table = soup.find("table", class_="wikitable")
    df = pd.read_html(StringIO(str(table)))[0]  # 첫 번째 테이블만 가져오기

    # 컬럼 이름 설정
    df.columns = [
        "Country",
        "IMF_Forecast",
        "IMF_Year",
        "World_Bank_Estimate",
        "World_Bank_Year",
        "UN_Estimate",
        "UN_Year",
    ]
    df = df[["Country", "IMF_Forecast"]]
    log("extract end")
    return df


# 데이터 전처리 함수 정의
def preprocess_gdp(row):
    data = {}

    # 국가명 처리
    if pd.notna(row["Country"]):
        if row["Country"] != "World":
            data["Country"] = row["Country"]

    # gdp 처리
    if pd.notna(row["IMF_Forecast"]) and row["IMF_Forecast"] != "—":
        data["GDP_USD_billion"] = round(
            int(row["IMF_Forecast"].replace(",", "")) / 1000, 2
        )

    if len(data) > 1:
        return data


def transform_data(preprocess_gdp, df):
    log("transform start")
    gdp_data = df.apply(preprocess_gdp, axis=1).tolist()
    gdp_data = [entry for entry in gdp_data if entry is not None]
    log("transform end")
    return gdp_data


# 크롤링 후, 데이터 전처리 적용
df = make_df()
gdp_data = transform_data(preprocess_gdp, df)


# 결과 출력
# for data in gdp_data:
#     if data:
#         print(data)

# %% [markdown]
#  - GDP가 100B USD이상이 되는 국가만을 구해서 화면에 출력해야 합니다.

# %%
gdp_over_100B_print(gdp_data)
# Out:
# United States  -  28781.08
# China  -  18532.63
# Germany  -  4591.1
# Japan  -  4110.45
# India  -  3937.01
# United Kingdom  -  3495.26
# France  -  3130.01
# Brazil  -  2331.39
# Italy  -  2328.03
# Canada  -  2242.18
# Russia  -  2056.84
# Mexico  -  2017.03
# Australia  -  1790.35
# South Korea  -  1760.95
# Spain  -  1647.11
# Indonesia  -  1475.69
# Netherlands  -  1142.51
# Turkey  -  1113.56
# Saudi Arabia  -  1106.02
# Switzerland  -  938.46
# Poland  -  844.62
# Taiwan  -  802.96
# Belgium  -  655.19
# Sweden  -  623.05
# Argentina  -  604.26
# Ireland  -  564.02
# Thailand  -  548.89
# Austria  -  540.89
# Israel  -  530.66
# United Arab Emirates  -  527.8
# Norway  -  526.95
# Singapore  -  525.23
# Philippines  -  471.52
# Vietnam  -  465.81
# Iran  -  464.18
# Bangladesh  -  455.16
# Malaysia  -  445.52
# Denmark  -  409.99
# Hong Kong  -  406.77
# Colombia  -  386.08
# South Africa  -  373.23
# Romania  -  369.97
# Egypt  -  347.59
# Pakistan  -  338.24
# Chile  -  333.76
# Czech Republic  -  325.88
# Finland  -  308.06
# Portugal  -  298.95
# Kazakhstan  -  296.74
# Peru  -  282.46
# Algeria  -  266.78
# Iraq  -  265.89
# New Zealand  -  257.62
# Nigeria  -  252.74
# Greece  -  250.28
# Qatar  -  244.69
# Hungary  -  223.41
# Ethiopia  -  205.13
# Ukraine  -  188.94
# Kuwait  -  160.4
# Morocco  -  152.38
# Slovakia  -  140.81
# Dominican Republic  -  127.36
# Ecuador  -  121.59
# Puerto Rico  -  117.76
# Guatemala  -  110.03
# Oman  -  108.93
# Bulgaria  -  107.93
# Kenya  -  104.0
# Venezuela  -  102.33

# %% [markdown]
#  - 추출 (Extract)한 정보는 'Countries_by_GDP.json'라는 이름의 JSON 화일 포맷으로 저장해야 합니다.

# %%
gdp_to_json(gdp_data)

# %%
gdp_data
# Out:
# [{'Country': 'United States', 'GDP_USD_billion': 28781.08},
#  {'Country': 'China', 'GDP_USD_billion': 18532.63},
#  {'Country': 'Germany', 'GDP_USD_billion': 4591.1},
#  {'Country': 'Japan', 'GDP_USD_billion': 4110.45},
#  {'Country': 'India', 'GDP_USD_billion': 3937.01},
#  {'Country': 'United Kingdom', 'GDP_USD_billion': 3495.26},
#  {'Country': 'France', 'GDP_USD_billion': 3130.01},
#  {'Country': 'Brazil', 'GDP_USD_billion': 2331.39},
#  {'Country': 'Italy', 'GDP_USD_billion': 2328.03},
#  {'Country': 'Canada', 'GDP_USD_billion': 2242.18},
#  {'Country': 'Russia', 'GDP_USD_billion': 2056.84},
#  {'Country': 'Mexico', 'GDP_USD_billion': 2017.03},
#  {'Country': 'Australia', 'GDP_USD_billion': 1790.35},
#  {'Country': 'South Korea', 'GDP_USD_billion': 1760.95},
#  {'Country': 'Spain', 'GDP_USD_billion': 1647.11},
#  {'Country': 'Indonesia', 'GDP_USD_billion': 1475.69},
#  {'Country': 'Netherlands', 'GDP_USD_billion': 1142.51},
#  {'Country': 'Turkey', 'GDP_USD_billion': 1113.56},
#  {'Country': 'Saudi Arabia', 'GDP_USD_billion': 1106.02},
#  {'Country': 'Switzerland', 'GDP_USD_billion': 938.46},
#  {'Country': 'Poland', 'GDP_USD_billion': 844.62},
#  {'Country': 'Taiwan', 'GDP_USD_billion': 802.96},
#  {'Country': 'Belgium', 'GDP_USD_billion': 655.19},
#  {'Country': 'Sweden', 'GDP_USD_billion': 623.05},
#  {'Country': 'Argentina', 'GDP_USD_billion': 604.26},
#  {'Country': 'Ireland', 'GDP_USD_billion': 564.02},
#  {'Country': 'Thailand', 'GDP_USD_billion': 548.89},
#  {'Country': 'Austria', 'GDP_USD_billion': 540.89},
#  {'Country': 'Israel', 'GDP_USD_billion': 530.66},
#  {'Country': 'United Arab Emirates', 'GDP_USD_billion': 527.8},
#  {'Country': 'Norway', 'GDP_USD_billion': 526.95},
#  {'Country': 'Singapore', 'GDP_USD_billion': 525.23},
#  {'Country': 'Philippines', 'GDP_USD_billion': 471.52},
#  {'Country': 'Vietnam', 'GDP_USD_billion': 465.81},
#  {'Country': 'Iran', 'GDP_USD_billion': 464.18},
#  {'Country': 'Bangladesh', 'GDP_USD_billion': 455.16},
#  {'Country': 'Malaysia', 'GDP_USD_billion': 445.52},
#  {'Country': 'Denmark', 'GDP_USD_billion': 409.99},
#  {'Country': 'Hong Kong', 'GDP_USD_billion': 406.77},
#  {'Country': 'Colombia', 'GDP_USD_billion': 386.08},
#  {'Country': 'South Africa', 'GDP_USD_billion': 373.23},
#  {'Country': 'Romania', 'GDP_USD_billion': 369.97},
#  {'Country': 'Egypt', 'GDP_USD_billion': 347.59},
#  {'Country': 'Pakistan', 'GDP_USD_billion': 338.24},
#  {'Country': 'Chile', 'GDP_USD_billion': 333.76},
#  {'Country': 'Czech Republic', 'GDP_USD_billion': 325.88},
#  {'Country': 'Finland', 'GDP_USD_billion': 308.06},
#  {'Country': 'Portugal', 'GDP_USD_billion': 298.95},
#  {'Country': 'Kazakhstan', 'GDP_USD_billion': 296.74},
#  {'Country': 'Peru', 'GDP_USD_billion': 282.46},
#  {'Country': 'Algeria', 'GDP_USD_billion': 266.78},
#  {'Country': 'Iraq', 'GDP_USD_billion': 265.89},
#  {'Country': 'New Zealand', 'GDP_USD_billion': 257.62},
#  {'Country': 'Nigeria', 'GDP_USD_billion': 252.74},
#  {'Country': 'Greece', 'GDP_USD_billion': 250.28},
#  {'Country': 'Qatar', 'GDP_USD_billion': 244.69},
#  {'Country': 'Hungary', 'GDP_USD_billion': 223.41},
#  {'Country': 'Ethiopia', 'GDP_USD_billion': 205.13},
#  {'Country': 'Ukraine', 'GDP_USD_billion': 188.94},
#  {'Country': 'Kuwait', 'GDP_USD_billion': 160.4},
#  {'Country': 'Morocco', 'GDP_USD_billion': 152.38},
#  {'Country': 'Slovakia', 'GDP_USD_billion': 140.81},
#  {'Country': 'Dominican Republic', 'GDP_USD_billion': 127.36},
#  {'Country': 'Ecuador', 'GDP_USD_billion': 121.59},
#  {'Country': 'Puerto Rico', 'GDP_USD_billion': 117.76},
#  {'Country': 'Guatemala', 'GDP_USD_billion': 110.03},
#  {'Country': 'Oman', 'GDP_USD_billion': 108.93},
#  {'Country': 'Bulgaria', 'GDP_USD_billion': 107.93},
#  {'Country': 'Kenya', 'GDP_USD_billion': 104.0},
#  {'Country': 'Venezuela', 'GDP_USD_billion': 102.33},
#  {'Country': 'Uzbekistan', 'GDP_USD_billion': 97.96},
#  {'Country': 'Costa Rica', 'GDP_USD_billion': 96.06},
#  {'Country': 'Angola', 'GDP_USD_billion': 92.12},
#  {'Country': 'Luxembourg', 'GDP_USD_billion': 88.56},
#  {'Country': 'Croatia', 'GDP_USD_billion': 88.08},
#  {'Country': 'Panama', 'GDP_USD_billion': 87.35},
#  {'Country': 'Ivory Coast', 'GDP_USD_billion': 86.91},
#  {'Country': 'Uruguay', 'GDP_USD_billion': 82.61},
#  {'Country': 'Turkmenistan', 'GDP_USD_billion': 81.9},
#  {'Country': 'Serbia', 'GDP_USD_billion': 81.87},
#  {'Country': 'Lithuania', 'GDP_USD_billion': 81.17},
#  {'Country': 'Tanzania', 'GDP_USD_billion': 79.61},
#  {'Country': 'Azerbaijan', 'GDP_USD_billion': 78.75},
#  {'Country': 'Ghana', 'GDP_USD_billion': 75.24},
#  {'Country': 'Sri Lanka', 'GDP_USD_billion': 74.85},
#  {'Country': 'DR Congo', 'GDP_USD_billion': 73.76},
#  {'Country': 'Slovenia', 'GDP_USD_billion': 72.1},
#  {'Country': 'Belarus', 'GDP_USD_billion': 69.05},
#  {'Country': 'Myanmar', 'GDP_USD_billion': 68.01},
#  {'Country': 'Uganda', 'GDP_USD_billion': 56.31},
#  {'Country': 'Tunisia', 'GDP_USD_billion': 54.71},
#  {'Country': 'Macau', 'GDP_USD_billion': 54.68},
#  {'Country': 'Jordan', 'GDP_USD_billion': 53.57},
#  {'Country': 'Cameroon', 'GDP_USD_billion': 53.2},
#  {'Country': 'Bolivia', 'GDP_USD_billion': 49.33},
#  {'Country': 'Libya', 'GDP_USD_billion': 48.22},
#  {'Country': 'Bahrain', 'GDP_USD_billion': 46.79},
#  {'Country': 'Paraguay', 'GDP_USD_billion': 45.82},
#  {'Country': 'Latvia', 'GDP_USD_billion': 45.47},
#  {'Country': 'Cambodia', 'GDP_USD_billion': 45.15},
#  {'Country': 'Nepal', 'GDP_USD_billion': 44.18},
#  {'Country': 'Estonia', 'GDP_USD_billion': 43.49},
#  {'Country': 'Honduras', 'GDP_USD_billion': 37.35},
#  {'Country': 'Senegal', 'GDP_USD_billion': 35.45},
#  {'Country': 'El Salvador', 'GDP_USD_billion': 35.33},
#  {'Country': 'Zimbabwe', 'GDP_USD_billion': 34.41},
#  {'Country': 'Cyprus', 'GDP_USD_billion': 34.22},
#  {'Country': 'Iceland', 'GDP_USD_billion': 33.34},
#  {'Country': 'Georgia', 'GDP_USD_billion': 32.87},
#  {'Country': 'Papua New Guinea', 'GDP_USD_billion': 31.72},
#  {'Country': 'Zambia', 'GDP_USD_billion': 29.87},
#  {'Country': 'Bosnia and Herzegovina', 'GDP_USD_billion': 29.08},
#  {'Country': 'Trinidad and Tobago', 'GDP_USD_billion': 28.36},
#  {'Country': 'Sudan', 'GDP_USD_billion': 26.86},
#  {'Country': 'Guinea', 'GDP_USD_billion': 25.45},
#  {'Country': 'Albania', 'GDP_USD_billion': 25.43},
#  {'Country': 'Armenia', 'GDP_USD_billion': 25.41},
#  {'Country': 'Haiti', 'GDP_USD_billion': 24.05},
#  {'Country': 'Mozambique', 'GDP_USD_billion': 22.98},
#  {'Country': 'Malta', 'GDP_USD_billion': 22.74},
#  {'Country': 'Mongolia', 'GDP_USD_billion': 21.94},
#  {'Country': 'Burkina Faso', 'GDP_USD_billion': 21.9},
#  {'Country': 'Lebanon', 'GDP_USD_billion': 21.78},
#  {'Country': 'Mali', 'GDP_USD_billion': 21.66},
#  {'Country': 'Botswana', 'GDP_USD_billion': 21.42},
#  {'Country': 'Benin', 'GDP_USD_billion': 21.37},
#  {'Country': 'Guyana', 'GDP_USD_billion': 21.18},
#  {'Country': 'Gabon', 'GDP_USD_billion': 21.01},
#  {'Country': 'Jamaica', 'GDP_USD_billion': 20.1},
#  {'Country': 'Nicaragua', 'GDP_USD_billion': 18.83},
#  {'Country': 'Niger', 'GDP_USD_billion': 18.82},
#  {'Country': 'Chad', 'GDP_USD_billion': 18.7},
#  {'Country': 'Palestine', 'GDP_USD_billion': 18.6},
#  {'Country': 'Moldova', 'GDP_USD_billion': 18.36},
#  {'Country': 'Yemen', 'GDP_USD_billion': 16.94},
#  {'Country': 'Madagascar', 'GDP_USD_billion': 16.46},
#  {'Country': 'Mauritius', 'GDP_USD_billion': 16.36},
#  {'Country': 'North Macedonia', 'GDP_USD_billion': 15.87},
#  {'Country': 'Brunei', 'GDP_USD_billion': 15.51},
#  {'Country': 'Congo', 'GDP_USD_billion': 15.5},
#  {'Country': 'Laos', 'GDP_USD_billion': 15.19},
#  {'Country': 'Afghanistan', 'GDP_USD_billion': 14.47},
#  {'Country': 'Bahamas', 'GDP_USD_billion': 14.39},
#  {'Country': 'Rwanda', 'GDP_USD_billion': 13.7},
#  {'Country': 'Kyrgyzstan', 'GDP_USD_billion': 13.6},
#  {'Country': 'Tajikistan', 'GDP_USD_billion': 12.95},
#  {'Country': 'Somalia', 'GDP_USD_billion': 12.8},
#  {'Country': 'Namibia', 'GDP_USD_billion': 12.77},
#  {'Country': 'Kosovo', 'GDP_USD_billion': 11.32},
#  {'Country': 'Malawi', 'GDP_USD_billion': 11.24},
#  {'Country': 'Equatorial Guinea', 'GDP_USD_billion': 10.71},
#  {'Country': 'Mauritania', 'GDP_USD_billion': 10.63},
#  {'Country': 'Togo', 'GDP_USD_billion': 9.83},
#  {'Country': 'Montenegro', 'GDP_USD_billion': 8.01},
#  {'Country': 'Maldives', 'GDP_USD_billion': 7.2},
#  {'Country': 'Barbados', 'GDP_USD_billion': 6.86},
#  {'Country': 'South Sudan', 'GDP_USD_billion': 6.52},
#  {'Country': 'Fiji', 'GDP_USD_billion': 5.8},
#  {'Country': 'Eswatini', 'GDP_USD_billion': 5.08},
#  {'Country': 'Liberia', 'GDP_USD_billion': 4.75},
#  {'Country': 'Sierra Leone', 'GDP_USD_billion': 4.56},
#  {'Country': 'Djibouti', 'GDP_USD_billion': 4.36},
#  {'Country': 'Suriname', 'GDP_USD_billion': 4.34},
#  {'Country': 'Aruba', 'GDP_USD_billion': 4.07},
#  {'Country': 'Andorra', 'GDP_USD_billion': 3.9},
#  {'Country': 'Belize', 'GDP_USD_billion': 3.3},
#  {'Country': 'Bhutan', 'GDP_USD_billion': 3.11},
#  {'Country': 'Burundi', 'GDP_USD_billion': 3.08},
#  {'Country': 'Central African Republic', 'GDP_USD_billion': 2.81},
#  {'Country': 'Cape Verde', 'GDP_USD_billion': 2.72},
#  {'Country': 'Gambia', 'GDP_USD_billion': 2.69},
#  {'Country': 'Saint Lucia', 'GDP_USD_billion': 2.58},
#  {'Country': 'Lesotho', 'GDP_USD_billion': 2.4},
#  {'Country': 'Seychelles', 'GDP_USD_billion': 2.2},
#  {'Country': 'Guinea-Bissau', 'GDP_USD_billion': 2.15},
#  {'Country': 'Antigua and Barbuda', 'GDP_USD_billion': 2.13},
#  {'Country': 'San Marino', 'GDP_USD_billion': 2.03},
#  {'Country': 'East Timor', 'GDP_USD_billion': 1.99},
#  {'Country': 'Solomon Islands', 'GDP_USD_billion': 1.71},
#  {'Country': 'Comoros', 'GDP_USD_billion': 1.42},
#  {'Country': 'Grenada', 'GDP_USD_billion': 1.41},
#  {'Country': 'Vanuatu', 'GDP_USD_billion': 1.29},
#  {'Country': 'Saint Kitts and Nevis', 'GDP_USD_billion': 1.13},
#  {'Country': 'Saint Vincent and the Grenadines', 'GDP_USD_billion': 1.13},
#  {'Country': 'Samoa', 'GDP_USD_billion': 1.02},
#  {'Country': 'São Tomé and Príncipe', 'GDP_USD_billion': 0.75},
#  {'Country': 'Dominica', 'GDP_USD_billion': 0.71},
#  {'Country': 'Tonga', 'GDP_USD_billion': 0.58},
#  {'Country': 'Micronesia', 'GDP_USD_billion': 0.48},
#  {'Country': 'Kiribati', 'GDP_USD_billion': 0.31},
#  {'Country': 'Palau', 'GDP_USD_billion': 0.31},
#  {'Country': 'Marshall Islands', 'GDP_USD_billion': 0.3},
#  {'Country': 'Nauru', 'GDP_USD_billion': 0.16},
#  {'Country': 'Tuvalu', 'GDP_USD_billion': 0.07}]

# %%
from etl_project_gdp_with_sql import *

create_table()
delete_table()
insert_data_to_table(gdp_data)
data = select_all_data()
for d in data:
    print(d)
# Out:
# (1, 'United States', 28781.08)
# (2, 'China', 18532.63)
# (3, 'Germany', 4591.1)
# (4, 'Japan', 4110.45)
# (5, 'India', 3937.01)
# (6, 'United Kingdom', 3495.26)
# (7, 'France', 3130.01)
# (8, 'Brazil', 2331.39)
# (9, 'Italy', 2328.03)
# (10, 'Canada', 2242.18)
# (11, 'Russia', 2056.84)
# (12, 'Mexico', 2017.03)
# (13, 'Australia', 1790.35)
# (14, 'South Korea', 1760.95)
# (15, 'Spain', 1647.11)
# (16, 'Indonesia', 1475.69)
# (17, 'Netherlands', 1142.51)
# (18, 'Turkey', 1113.56)
# (19, 'Saudi Arabia', 1106.02)
# (20, 'Switzerland', 938.46)
# (21, 'Poland', 844.62)
# (22, 'Taiwan', 802.96)
# (23, 'Belgium', 655.19)
# (24, 'Sweden', 623.05)
# (25, 'Argentina', 604.26)
# (26, 'Ireland', 564.02)
# (27, 'Thailand', 548.89)
# (28, 'Austria', 540.89)
# (29, 'Israel', 530.66)
# (30, 'United Arab Emirates', 527.8)
# (31, 'Norway', 526.95)
# (32, 'Singapore', 525.23)
# (33, 'Philippines', 471.52)
# (34, 'Vietnam', 465.81)
# (35, 'Iran', 464.18)
# (36, 'Bangladesh', 455.16)
# (37, 'Malaysia', 445.52)
# (38, 'Denmark', 409.99)
# (39, 'Hong Kong', 406.77)
# (40, 'Colombia', 386.08)
# (41, 'South Africa', 373.23)
# (42, 'Romania', 369.97)
# (43, 'Egypt', 347.59)
# (44, 'Pakistan', 338.24)
# (45, 'Chile', 333.76)
# (46, 'Czech Republic', 325.88)
# (47, 'Finland', 308.06)
# (48, 'Portugal', 298.95)
# (49, 'Kazakhstan', 296.74)
# (50, 'Peru', 282.46)
# (51, 'Algeria', 266.78)
# (52, 'Iraq', 265.89)
# (53, 'New Zealand', 257.62)
# (54, 'Nigeria', 252.74)
# (55, 'Greece', 250.28)
# (56, 'Qatar', 244.69)
# (57, 'Hungary', 223.41)
# (58, 'Ethiopia', 205.13)
# (59, 'Ukraine', 188.94)
# (60, 'Kuwait', 160.4)
# (61, 'Morocco', 152.38)
# (62, 'Slovakia', 140.81)
# (63, 'Dominican Republic', 127.36)
# (64, 'Ecuador', 121.59)
# (65, 'Puerto Rico', 117.76)
# (66, 'Guatemala', 110.03)
# (67, 'Oman', 108.93)
# (68, 'Bulgaria', 107.93)
# (69, 'Kenya', 104)
# (70, 'Venezuela', 102.33)
# (71, 'Uzbekistan', 97.96)
# (72, 'Costa Rica', 96.06)
# (73, 'Angola', 92.12)
# (74, 'Luxembourg', 88.56)
# (75, 'Croatia', 88.08)
# (76, 'Panama', 87.35)
# (77, 'Ivory Coast', 86.91)
# (78, 'Uruguay', 82.61)
# (79, 'Turkmenistan', 81.9)
# (80, 'Serbia', 81.87)
# (81, 'Lithuania', 81.17)
# (82, 'Tanzania', 79.61)
# (83, 'Azerbaijan', 78.75)
# (84, 'Ghana', 75.24)
# (85, 'Sri Lanka', 74.85)
# (86, 'DR Congo', 73.76)
# (87, 'Slovenia', 72.1)
# (88, 'Belarus', 69.05)
# (89, 'Myanmar', 68.01)
# (90, 'Uganda', 56.31)
# (91, 'Tunisia', 54.71)
# (92, 'Macau', 54.68)
# (93, 'Jordan', 53.57)
# (94, 'Cameroon', 53.2)
# (95, 'Bolivia', 49.33)
# (96, 'Libya', 48.22)
# (97, 'Bahrain', 46.79)
# (98, 'Paraguay', 45.82)
# (99, 'Latvia', 45.47)
# (100, 'Cambodia', 45.15)
# (101, 'Nepal', 44.18)
# (102, 'Estonia', 43.49)
# (103, 'Honduras', 37.35)
# (104, 'Senegal', 35.45)
# (105, 'El Salvador', 35.33)
# (106, 'Zimbabwe', 34.41)
# (107, 'Cyprus', 34.22)
# (108, 'Iceland', 33.34)
# (109, 'Georgia', 32.87)
# (110, 'Papua New Guinea', 31.72)
# (111, 'Zambia', 29.87)
# (112, 'Bosnia and Herzegovina', 29.08)
# (113, 'Trinidad and Tobago', 28.36)
# (114, 'Sudan', 26.86)
# (115, 'Guinea', 25.45)
# (116, 'Albania', 25.43)
# (117, 'Armenia', 25.41)
# (118, 'Haiti', 24.05)
# (119, 'Mozambique', 22.98)
# (120, 'Malta', 22.74)
# (121, 'Mongolia', 21.94)
# (122, 'Burkina Faso', 21.9)
# (123, 'Lebanon', 21.78)
# (124, 'Mali', 21.66)
# (125, 'Botswana', 21.42)
# (126, 'Benin', 21.37)
# (127, 'Guyana', 21.18)
# (128, 'Gabon', 21.01)
# (129, 'Jamaica', 20.1)
# (130, 'Nicaragua', 18.83)
# (131, 'Niger', 18.82)
# (132, 'Chad', 18.7)
# (133, 'Palestine', 18.6)
# (134, 'Moldova', 18.36)
# (135, 'Yemen', 16.94)
# (136, 'Madagascar', 16.46)
# (137, 'Mauritius', 16.36)
# (138, 'North Macedonia', 15.87)
# (139, 'Brunei', 15.51)
# (140, 'Congo', 15.5)
# (141, 'Laos', 15.19)
# (142, 'Afghanistan', 14.47)
# (143, 'Bahamas', 14.39)
# (144, 'Rwanda', 13.7)
# (145, 'Kyrgyzstan', 13.6)
# (146, 'Tajikistan', 12.95)
# (147, 'Somalia', 12.8)
# (148, 'Namibia', 12.77)
# (149, 'Kosovo', 11.32)
# (150, 'Malawi', 11.24)
# (151, 'Equatorial Guinea', 10.71)
# (152, 'Mauritania', 10.63)
# (153, 'Togo', 9.83)
# (154, 'Montenegro', 8.01)
# (155, 'Maldives', 7.2)
# (156, 'Barbados', 6.86)
# (157, 'South Sudan', 6.52)
# (158, 'Fiji', 5.8)
# (159, 'Eswatini', 5.08)
# (160, 'Liberia', 4.75)
# (161, 'Sierra Leone', 4.56)
# (162, 'Djibouti', 4.36)
# (163, 'Suriname', 4.34)
# (164, 'Aruba', 4.07)
# (165, 'Andorra', 3.9)
# (166, 'Belize', 3.3)
# (167, 'Bhutan', 3.11)
# (168, 'Burundi', 3.08)
# (169, 'Central African Republic', 2.81)
# (170, 'Cape Verde', 2.72)
# (171, 'Gambia', 2.69)
# (172, 'Saint Lucia', 2.58)
# (173, 'Lesotho', 2.4)
# (174, 'Seychelles', 2.2)
# (175, 'Guinea-Bissau', 2.15)
# (176, 'Antigua and Barbuda', 2.13)
# (177, 'San Marino', 2.03)
# (178, 'East Timor', 1.99)
# (179, 'Solomon Islands', 1.71)
# (180, 'Comoros', 1.42)
# (181, 'Grenada', 1.41)
# (182, 'Vanuatu', 1.29)
# (183, 'Saint Kitts and Nevis', 1.13)
# (184, 'Saint Vincent and the Grenadines', 1.13)
# (185, 'Samoa', 1.02)
# (186, 'São Tomé and Príncipe', 0.75)
# (187, 'Dominica', 0.71)
# (188, 'Tonga', 0.58)
# (189, 'Micronesia', 0.48)
# (190, 'Kiribati', 0.31)
# (191, 'Palau', 0.31)
# (192, 'Marshall Islands', 0.3)
# (193, 'Nauru', 0.16)
# (194, 'Tuvalu', 0.07)

# %%
from etl_project_gdp_with_sql import select_gdp_over_100B


over_100B_data = select_gdp_over_100B()
for data in over_100B_data:
    print(data)
# Out:
# (1, 'United States', 28781.08)
# (2, 'China', 18532.63)
# (3, 'Germany', 4591.1)
# (4, 'Japan', 4110.45)
# (5, 'India', 3937.01)
# (6, 'United Kingdom', 3495.26)
# (7, 'France', 3130.01)
# (8, 'Brazil', 2331.39)
# (9, 'Italy', 2328.03)
# (10, 'Canada', 2242.18)
# (11, 'Russia', 2056.84)
# (12, 'Mexico', 2017.03)
# (13, 'Australia', 1790.35)
# (14, 'South Korea', 1760.95)
# (15, 'Spain', 1647.11)
# (16, 'Indonesia', 1475.69)
# (17, 'Netherlands', 1142.51)
# (18, 'Turkey', 1113.56)
# (19, 'Saudi Arabia', 1106.02)
# (20, 'Switzerland', 938.46)
# (21, 'Poland', 844.62)
# (22, 'Taiwan', 802.96)
# (23, 'Belgium', 655.19)
# (24, 'Sweden', 623.05)
# (25, 'Argentina', 604.26)
# (26, 'Ireland', 564.02)
# (27, 'Thailand', 548.89)
# (28, 'Austria', 540.89)
# (29, 'Israel', 530.66)
# (30, 'United Arab Emirates', 527.8)
# (31, 'Norway', 526.95)
# (32, 'Singapore', 525.23)
# (33, 'Philippines', 471.52)
# (34, 'Vietnam', 465.81)
# (35, 'Iran', 464.18)
# (36, 'Bangladesh', 455.16)
# (37, 'Malaysia', 445.52)
# (38, 'Denmark', 409.99)
# (39, 'Hong Kong', 406.77)
# (40, 'Colombia', 386.08)
# (41, 'South Africa', 373.23)
# (42, 'Romania', 369.97)
# (43, 'Egypt', 347.59)
# (44, 'Pakistan', 338.24)
# (45, 'Chile', 333.76)
# (46, 'Czech Republic', 325.88)
# (47, 'Finland', 308.06)
# (48, 'Portugal', 298.95)
# (49, 'Kazakhstan', 296.74)
# (50, 'Peru', 282.46)
# (51, 'Algeria', 266.78)
# (52, 'Iraq', 265.89)
# (53, 'New Zealand', 257.62)
# (54, 'Nigeria', 252.74)
# (55, 'Greece', 250.28)
# (56, 'Qatar', 244.69)
# (57, 'Hungary', 223.41)
# (58, 'Ethiopia', 205.13)
# (59, 'Ukraine', 188.94)
# (60, 'Kuwait', 160.4)
# (61, 'Morocco', 152.38)
# (62, 'Slovakia', 140.81)
# (63, 'Dominican Republic', 127.36)
# (64, 'Ecuador', 121.59)
# (65, 'Puerto Rico', 117.76)
# (66, 'Guatemala', 110.03)
# (67, 'Oman', 108.93)
# (68, 'Bulgaria', 107.93)
# (69, 'Kenya', 104)
# (70, 'Venezuela', 102.33)
